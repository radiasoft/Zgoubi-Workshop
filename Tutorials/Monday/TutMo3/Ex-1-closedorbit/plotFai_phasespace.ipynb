# %%
# %matplotlib inline
import numpy as np
import pylab as plt
import sys
import os

#Alternatively, use numpy loadtxt to read the columns directly.
FL=os.getcwd()
coords = np.loadtxt('%s/%s'%(FL,'zgoubi_iter2.fai'),skiprows=2,usecols=(9,10,11,12),unpack=True)

#y,t,z,p are the horizontal coordinate and angle and the vertical coordinate and angle, respectively.
y, t, z, p = coords

y_mean = np.mean(y)
t_mean = np.mean(t)

print "mean x,x' (cm)",y_mean, t_mean
print "max - min x, x' (cm) ",max(y)-min(y)
plt.plot(y,t, 'ko')
plt.plot([y_mean], [t_mean],'ro',label='{<x>,<x\'>}')
plt.xlabel('x [cm]')
plt.ylabel('x\' [mrad]')
plt.title('Horizontal phase space')
#plt.legend()
plt.show()
# Out:
# mean x,x' (cm) 517.5431277235166 3.8139485738286645e-05
# max - min x, x' (cm)  0.0010813999175525169
